# %% [markdown]
# ### 텍스트 정규화
# 텍스트를 가공하는 준비 작업
#
# - 클렌징 (Cleansing)
# - 토큰화 (Tokenization)
# - 필터링/스톱워드 제거/철자 수정
# - Stemming
# - Lemmatization

# %% [markdown]
# ### 텍스트 토큰화
# - 문장 토큰화 : 문장의 마침표, 개행문자(\n)등 문자의 마지막을 뜻하는 기호에 따라 분리하는 것
# - 단어 토큰화 : 문장을 단어로 토큰화하는 것

# %%
# !pip install nltk

# %%
from nltk import sent_tokenize
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lnyln\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\lnyln\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
# 문장 토큰화
from nltk import sent_tokenize

text_sample = "Hello, My name is Nayoung. \
This is sample. \
I want to go to sleep."
sentences = sent_tokenize(text=text_sample)
print(type(sentences),len(sentences))
print(sentences)
# Out:
# <class 'list'> 3
# ['Hello, My name is Nayoung.', 'This is sample.', 'I want to go to sleep.']

# %%
# 단어 토큰화
from nltk import word_tokenize

sentence = "Hello, My name is Nayoung."
words = word_tokenize(sentence)
print(type(words),len(words))
print(words)
# Out:
# <class 'list'> 7
# ['Hello', ',', 'My', 'name', 'is', 'Nayoung', '.']

# %%
from nltk import word_tokenize, sent_tokenize

# 여러 개의 문장으로 된 입력데이터를 문장 별로 단어 토큰화하게 만드는 함수 생성
def tokenize_text(text) :
    # 문장별로 분리 토큰
    sentences = sent_tokenize(text)
    # 분리된 문장별 단어 토큰화
    word_tokens = [word_tokenize(sentence) for sentence in sentences]
    return word_tokens

# 여러 문장에 대해 문장별 단어 토큰화 수행
word_tokens = tokenize_text(text_sample)
print(type(word_tokens),len(word_tokens))
print(word_tokens)
# Out:
# <class 'list'> 3
# [['Hello', ',', 'My', 'name', 'is', 'Nayoung', '.'], ['This', 'is', 'sample', '.'], ['I', 'want', 'to', 'go', 'to', 'sleep', '.']]

# %%
# 스톱 워드 제거 (의미가 없는 단어)

import nltk
nltk.download('stopwords')
